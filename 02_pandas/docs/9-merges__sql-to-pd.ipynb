# %%
# import libraries
import pandas as pd

# load data
# This code is made to load our data stored on Google Drive
def gd_path(file_id):
    """Generate a shareable link from Google Drive file id."""
    return f"https://drive.google.com/uc?export=download&id={file_id}"

# Google Drive file ids
files_id = {
    "titles": "1PLdn50N9GRa53ZbuVWo0l47F_IXdvlEm",
    "stores": "1f-GCgip7O93CpbAkYvOsc21eKnSOSHsQ",
    "sales": "1fzFc9rwYmVIPaGOFmhLVxCi3kg19vNU2",
    "publishers": "1s9E8_AVOziTrowb3wyh2jg3PV763VOyq",
    "pub_info": "1OEgogcGKy--EpuVj0kqq7lyBZNGW6YSv",
    "jobs": "1V1Za8hUdXD-vJOyRdX4aQV5wanIff2eM",
    "employee": "1h9mUjsVqpP74b1w0x7KOw37n_n9Ulkt5",
    "discounts": "111dvSxMcCsTgOuV1wDSKFJxO1Xcxd9VS",
}

# Read data from Google Drive
sales = pd.read_csv(gd_path(files_id["sales"]), sep=";")
titles = pd.read_csv(gd_path(files_id["titles"]), sep=";")
employee = pd.read_csv(gd_path(files_id["employee"]), sep=";")
stores = pd.read_csv(gd_path(files_id["stores"]), sep=";")
publishers = pd.read_csv(gd_path(files_id["publishers"]), sep=";")
# Replace the logos pandas can't read with '?'
pub_info = pd.read_csv(gd_path(files_id["pub_info"]), sep=";", encoding_errors = 'replace')
discounts = pd.read_csv(gd_path(files_id["discounts"]), sep=";")
jobs = pd.read_csv(gd_path(files_id["jobs"]), sep=";")

# %% [markdown]
# # From SQL to pandas challenge 9

# %% [markdown]
# ##  1.&nbsp;Select the table sales, assigning the alias "s" to it.
#    Select the column ord_num using the syntax `table_alias[column]`

# %%
s = sales
s.ord_num
# Out:
# 0         6871
# 1         722a
# 2        A2976
# 3     QA7442.3
# 4        D4482
# 5        P2121
# 6        P2121
# 7        P2121
# 8      N914008
# 9      N914014
# 10      P3087a
# 11      P3087a
# 12      P3087a
# 13      P3087a
# 14      QQ2299
# 15       TQ456
# 16        X999
# 17    423LL922
# 18    423LL930
# 19        P723
# 20     QA879.1
# Name: ord_num, dtype: object

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT s.ord_num
# FROM sales AS s;
# ```

# %% [markdown]
# ## 2.&nbsp;Select the title and publisher name of all books

# %%
t, p = titles, publishers
(
    t.merge(p, on='pub_id', how='left')
    [['title', 'pub_name']]
)
# Out:
#                                                 title              pub_name
# 0                 The Busy Executive's Database Guide  Algodata Infosystems
# 1   Cooking with Computers: Surreptitious Balance ...  Algodata Infosystems
# 2                     You Can Combat Computer Stress!        New Moon Books
# 3                       Straight Talk About Computers  Algodata Infosystems
# 4                   Silicon Valley Gastronomic Treats      Binnet & Hardley
# 5                               The Gourmet Microwave      Binnet & Hardley
# 6                  The Psychology of Computer Cooking      Binnet & Hardley
# 7                            But Is It User Friendly?  Algodata Infosystems
# 8                           Secrets of Silicon Valley  Algodata Infosystems
# 9                                       Net Etiquette  Algodata Infosystems
# 10  Computer Phobic AND Non-Phobic Individuals: Be...      Binnet & Hardley
# 11                                Is Anger the Enemy?        New Moon Books
# 12                                  Life Without Fear        New Moon Books
# 13      Prolonged Data Deprivation: Four Case Studies        New Moon Books
# 14                Emotional Security: A New Algorithm        New Moon Books
# 15  Onions, Leeks, and Garlic: Cooking Secrets of ...      Binnet & Hardley
# 16          Fifty Years in Buckingham Palace Kitchens      Binnet & Hardley
# 17                                     Sushi, Anyone?      Binnet & Hardley

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT t.title, p.pub_name
# FROM titles t
# LEFT JOIN publishers p ON t.pub_id = p.pub_id;
# ```

# %% [markdown]
# ## 3.&nbsp;Select the order number, quantity and book title for all sales.

# %%
(
    sales.join(titles.set_index('title_id'), on='title_id')
    [['ord_num', 'qty', 'title']]
)
# Out:
#      ord_num  qty                                              title
# 0       6871    5                The Busy Executive's Database Guide
# 1       722a    3                                Is Anger the Enemy?
# 2      A2976   50                          Secrets of Silicon Valley
# 3   QA7442.3   75                                Is Anger the Enemy?
# 4      D4482   10                                Is Anger the Enemy?
# 5      P2121   40  Onions, Leeks, and Garlic: Cooking Secrets of ...
# 6      P2121   20          Fifty Years in Buckingham Palace Kitchens
# 7      P2121   20                                     Sushi, Anyone?
# 8    N914008   20                                Is Anger the Enemy?
# 9    N914014   25                              The Gourmet Microwave
# 10    P3087a   20  Computer Phobic AND Non-Phobic Individuals: Be...
# 11    P3087a   25                                  Life Without Fear
# 12    P3087a   15      Prolonged Data Deprivation: Four Case Studies
# 13    P3087a   25                Emotional Security: A New Algorithm
# 14    QQ2299   15                      Straight Talk About Computers
# 15     TQ456   10                  Silicon Valley Gastronomic Treats
# 16      X999   35                    You Can Combat Computer Stress!
# 17  423LL922   15                              The Gourmet Microwave
# 18  423LL930   10                The Busy Executive's Database Guide
# 19      P723   25  Cooking with Computers: Surreptitious Balance ...
# 20   QA879.1   30                           But Is It User Friendly?

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT ord_num, qty, titles.title
# FROM sales
# LEFT JOIN titles
# ON sales.title_id=titles.title_id;
# ```

# %% [markdown]
# ## 4.&nbsp;Select the full name of all employees and the name of the publisher they work for

# %%
E, P = employee, publishers
(
    E.join(P.set_index('pub_id'), on='pub_id')
    .assign(full_name =
        E.fname
      + E.minit.apply(lambda minit:
          f' {minit}.' if pd.notnull(minit) else '')
      + ' '
      + E.lname)
    [['full_name', 'pub_name']]
)
# Out:
#                full_name               pub_name
# 0              Aria Cruz   Algodata Infosystems
# 1         Annette Roulet     Lucerne Publishing
# 2           Ann M. Devon         Scootney Books
# 3   Anabela R. Domingues       Binnet & Hardley
# 4     Carlos F. Hernadez     Lucerne Publishing
# 5      Carine G. Schmitt   Algodata Infosystems
# 6       Daniel B. Tonini       Binnet & Hardley
# 7          Diego W. Roel   Algodata Infosystems
# 8   Elizabeth N. Lincoln       Binnet & Hardley
# 9        Francisco Chang         Scootney Books
# 10        Gary H. Thomas         New Moon Books
# 11         Helen Bennett       Binnet & Hardley
# 12     Helvetius A. Nagy     Lucerne Publishing
# 13      Howard A. Snyder         New Moon Books
# 14     Janine Y. Labrune                  GGG&G
# 15      Karin F. Josephs         New Moon Books
# 16    Karla J. Jablonski     Lucerne Publishing
# 17          Lesley Brown       Binnet & Hardley
# 18   Laurence A. Lebihan         New Moon Books
# 19         Maria Larsson   Algodata Infosystems
# 20        Manuel Pereira     Lucerne Publishing
# 21         Martine Rance       Binnet & Hardley
# 22     Miguel A. Paolino   Algodata Infosystems
# 23     Margaret A. Smith   Algodata Infosystems
# 24      Martin F. Sommer         New Moon Books
# 25    Matti G. Karttunen         New Moon Books
# 26       Maria J. Pontes      Ramona Publishers
# 27       Mary M. Saveley         New Moon Books
# 28   Patricia C. McKenna     Lucerne Publishing
# 29        Palle D. Ibsen         New Moon Books
# 30      Peter H. Franken       Binnet & Hardley
# 31      Paolo M. Accorti       Binnet & Hardley
# 32   Pirkko O. Koskitalo     Lucerne Publishing
# 33       Pedro S. Afonso   Algodata Infosystems
# 34      Paula S. Parente   Algodata Infosystems
# 35      Philip T. Cramer         Scootney Books
# 36       Paul X. Henriot       Binnet & Hardley
# 37         Roland Mendel         New Moon Books
# 38        Rita B. Muller  Five Lakes Publishing
# 39       Sven K. Ottlieb   Algodata Infosystems
# 40   Timothy P. O'Rourke         New Moon Books
# 41  Victoria P. Ashworth       Binnet & Hardley
# 42         Yoshi Latimer   Algodata Infosystems

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# Select E.fname,E.lname,P.pub_name
# from employee E
# left join publishers P
# on E.pub_id=P.pub_id;
# ```

# %% [markdown]
# ## 5.&nbsp;Select the full name and job description of all employees.

# %%
E, J = employee, jobs
(
    E.join(J.set_index('job_id'), on='job_id')
    .assign(full_name =
        E.fname
      + E.minit.apply(lambda minit:
          f' {minit}.' if pd.notnull(minit) else '')
      + ' '
      + E.lname)
    [['full_name', 'job_desc']]
)
# Out:
#                full_name                     job_desc
# 0              Aria Cruz          Productions Manager
# 1         Annette Roulet              Managing Editor
# 2           Ann M. Devon  Business Operations Manager
# 3   Anabela R. Domingues     Public Relations Manager
# 4     Carlos F. Hernadez                    Publisher
# 5      Carine G. Schmitt         Sales Representative
# 6       Daniel B. Tonini           Operations Manager
# 7          Diego W. Roel              Managing Editor
# 8   Elizabeth N. Lincoln                     Designer
# 9        Francisco Chang     Chief Financial Officier
# 10        Gary H. Thomas         Acquisitions Manager
# 11         Helen Bennett                       Editor
# 12     Helvetius A. Nagy            Marketing Manager
# 13      Howard A. Snyder                       Editor
# 14     Janine Y. Labrune                    Publisher
# 15      Karin F. Josephs                     Designer
# 16    Karla J. Jablonski         Acquisitions Manager
# 17          Lesley Brown            Marketing Manager
# 18   Laurence A. Lebihan                    Publisher
# 19         Maria Larsson            Marketing Manager
# 20        Manuel Pereira     Public Relations Manager
# 21         Martine Rance         Acquisitions Manager
# 22     Miguel A. Paolino           Operations Manager
# 23     Margaret A. Smith         Acquisitions Manager
# 24      Martin F. Sommer          Productions Manager
# 25    Matti G. Karttunen              Managing Editor
# 26       Maria J. Pontes                    Publisher
# 27       Mary M. Saveley     Public Relations Manager
# 28   Patricia C. McKenna           Operations Manager
# 29        Palle D. Ibsen            Marketing Manager
# 30      Peter H. Franken          Productions Manager
# 31      Paolo M. Accorti         Sales Representative
# 32   Pirkko O. Koskitalo          Productions Manager
# 33       Pedro S. Afonso                     Designer
# 34      Paula S. Parente     Public Relations Manager
# 35      Philip T. Cramer      Chief Executive Officer
# 36       Paul X. Henriot                    Publisher
# 37         Roland Mendel           Operations Manager
# 38        Rita B. Muller                    Publisher
# 39       Sven K. Ottlieb                    Publisher
# 40   Timothy P. O'Rourke         Sales Representative
# 41  Victoria P. Ashworth              Managing Editor
# 42         Yoshi Latimer                       Editor

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT fname, lname, job_desc
# FROM employee
# LEFT JOIN jobs
# ON employee.job_id = jobs.job_id;
# ```

# %% [markdown]
# ## 6.&nbsp;Select the full name, job description and publisher name of all employees
#    Hint: you will have to perform 2 joins in a single query to merge 3 tables together.

# %%
E, P, J = employee, publishers, jobs
(
    E.join(P.set_index('pub_id'), on='pub_id')
    .join(J.set_index('job_id'), on='job_id')
    .assign(full_name =
        E.fname
      + E.minit.apply(lambda minit:
          f' {minit}.' if pd.notnull(minit) else '')
      + ' '
      + E.lname)
    [['full_name', 'job_desc', 'pub_name']]
)
# Out:
#                full_name                     job_desc               pub_name
# 0              Aria Cruz          Productions Manager   Algodata Infosystems
# 1         Annette Roulet              Managing Editor     Lucerne Publishing
# 2           Ann M. Devon  Business Operations Manager         Scootney Books
# 3   Anabela R. Domingues     Public Relations Manager       Binnet & Hardley
# 4     Carlos F. Hernadez                    Publisher     Lucerne Publishing
# 5      Carine G. Schmitt         Sales Representative   Algodata Infosystems
# 6       Daniel B. Tonini           Operations Manager       Binnet & Hardley
# 7          Diego W. Roel              Managing Editor   Algodata Infosystems
# 8   Elizabeth N. Lincoln                     Designer       Binnet & Hardley
# 9        Francisco Chang     Chief Financial Officier         Scootney Books
# 10        Gary H. Thomas         Acquisitions Manager         New Moon Books
# 11         Helen Bennett                       Editor       Binnet & Hardley
# 12     Helvetius A. Nagy            Marketing Manager     Lucerne Publishing
# 13      Howard A. Snyder                       Editor         New Moon Books
# 14     Janine Y. Labrune                    Publisher                  GGG&G
# 15      Karin F. Josephs                     Designer         New Moon Books
# 16    Karla J. Jablonski         Acquisitions Manager     Lucerne Publishing
# 17          Lesley Brown            Marketing Manager       Binnet & Hardley
# 18   Laurence A. Lebihan                    Publisher         New Moon Books
# 19         Maria Larsson            Marketing Manager   Algodata Infosystems
# 20        Manuel Pereira     Public Relations Manager     Lucerne Publishing
# 21         Martine Rance         Acquisitions Manager       Binnet & Hardley
# 22     Miguel A. Paolino           Operations Manager   Algodata Infosystems
# 23     Margaret A. Smith         Acquisitions Manager   Algodata Infosystems
# 24      Martin F. Sommer          Productions Manager         New Moon Books
# 25    Matti G. Karttunen              Managing Editor         New Moon Books
# 26       Maria J. Pontes                    Publisher      Ramona Publishers
# 27       Mary M. Saveley     Public Relations Manager         New Moon Books
# 28   Patricia C. McKenna           Operations Manager     Lucerne Publishing
# 29        Palle D. Ibsen            Marketing Manager         New Moon Books
# 30      Peter H. Franken          Productions Manager       Binnet & Hardley
# 31      Paolo M. Accorti         Sales Representative       Binnet & Hardley
# 32   Pirkko O. Koskitalo          Productions Manager     Lucerne Publishing
# 33       Pedro S. Afonso                     Designer   Algodata Infosystems
# 34      Paula S. Parente     Public Relations Manager   Algodata Infosystems
# 35      Philip T. Cramer      Chief Executive Officer         Scootney Books
# 36       Paul X. Henriot                    Publisher       Binnet & Hardley
# 37         Roland Mendel           Operations Manager         New Moon Books
# 38        Rita B. Muller                    Publisher  Five Lakes Publishing
# 39       Sven K. Ottlieb                    Publisher   Algodata Infosystems
# 40   Timothy P. O'Rourke         Sales Representative         New Moon Books
# 41  Victoria P. Ashworth              Managing Editor       Binnet & Hardley
# 42         Yoshi Latimer                       Editor   Algodata Infosystems

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT fname, lname, job_desc, pub_name
# FROM employee
# LEFT JOIN publishers
# ON employee.pub_id = publishers.pub_id
# LEFT JOIN jobs
# ON employee.job_id = jobs.job_id;
# ```

# %% [markdown]
# ## 7.&nbsp;Select the full name, job description and publisher name of employees that work for Binnet & Hardley.

# %%
E, P, J = employee, publishers, jobs
(
    E.join(P[P.pub_name == 'Binnet & Hardley'].set_index('pub_id'), on='pub_id', how='inner')
    .join(J.set_index('job_id'), on='job_id')
    .assign(full_name =
        E.fname
      + E.minit.apply(lambda minit:
          f' {minit}.' if pd.notnull(minit) else '')
      + ' '
      + E.lname)
    [['full_name', 'job_desc', 'pub_name']]
)
# Out:
#                full_name                  job_desc          pub_name
# 3   Anabela R. Domingues  Public Relations Manager  Binnet & Hardley
# 6       Daniel B. Tonini        Operations Manager  Binnet & Hardley
# 8   Elizabeth N. Lincoln                  Designer  Binnet & Hardley
# 11         Helen Bennett                    Editor  Binnet & Hardley
# 17          Lesley Brown         Marketing Manager  Binnet & Hardley
# 21         Martine Rance      Acquisitions Manager  Binnet & Hardley
# 30      Peter H. Franken       Productions Manager  Binnet & Hardley
# 31      Paolo M. Accorti      Sales Representative  Binnet & Hardley
# 36       Paul X. Henriot                 Publisher  Binnet & Hardley
# 41  Victoria P. Ashworth           Managing Editor  Binnet & Hardley

# %%
E, P, J = employee, publishers, jobs
(
    E.join(P.set_index('pub_id'), on='pub_id', how='inner')
    .join(J.set_index('job_id'), on='job_id')
    [lambda result: result.pub_name == 'Binnet & Hardley']
    .assign(full_name =
        E.fname
      + E.minit.apply(lambda minit:
          f' {minit}.' if pd.notnull(minit) else '')
      + ' '
      + E.lname)
    [['full_name', 'job_desc', 'pub_name']]
)
# Out:
#                full_name                  job_desc          pub_name
# 3   Anabela R. Domingues  Public Relations Manager  Binnet & Hardley
# 6       Daniel B. Tonini        Operations Manager  Binnet & Hardley
# 8   Elizabeth N. Lincoln                  Designer  Binnet & Hardley
# 11         Helen Bennett                    Editor  Binnet & Hardley
# 17          Lesley Brown         Marketing Manager  Binnet & Hardley
# 21         Martine Rance      Acquisitions Manager  Binnet & Hardley
# 30      Peter H. Franken       Productions Manager  Binnet & Hardley
# 31      Paolo M. Accorti      Sales Representative  Binnet & Hardley
# 36       Paul X. Henriot                 Publisher  Binnet & Hardley
# 41  Victoria P. Ashworth           Managing Editor  Binnet & Hardley

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT fname, lname, job_desc, pub_name
# FROM employee
# LEFT JOIN publishers
# ON employee.pub_id=publishers.pub_id
# LEFT JOIN jobs
# ON employee.job_id=jobs.job_id
# WHERE pub_name='Binnet & Hardley';
# ```

# %% [markdown]
# ## 8.&nbsp;Select the name and PR Info (from the pub_info table) from all publishers based in Berkeley, California.

# %%
(
    publishers[(publishers.city == 'Berkeley') & (publishers.state == 'CA')]
    .join(pub_info.set_index('pub_id'), on='pub_id')
    [['pub_name', 'pr_info']]
)
# Out:
#                pub_name                                            pr_info
# 2  Algodata Infosystems  This is sample text data for Algodata Infosyst...

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# select pub_name, pub_info.pr_info
# from publishers
# left join pub_info
# on pub_info.pub_id = publishers.pub_id
# where city in ("Berkeley") and state='CA';
#
# ```

# %% [markdown]
# ## 9.&nbsp;Selet all columns from the discounts table.
#    Observe the columns it has and now some of them are filled with NULL values.

# %%
discounts
# Out:
#         discounttype  stor_id  lowqty  highqty  discount
# 0   Initial Customer      NaN       0        0      10.5
# 1    Volume Discount      NaN     100     1000       6.7
# 2  Customer Discount   8042.0       0        0       5.0

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT * FROM discounts;
# ```

# %% [markdown]
# ## 10.&nbsp;Select all store names, their store id and the discounts they offer.
#
# 	   - When selecting the store id, select it two times: from the stores table
#          and from the discounts table.
#
#        - ALL stores should be displayed, even if they don't offer any discount
#          (i.e. have a NULL value on the discount column).

# %%
(
    stores.join(
        discounts.set_index('stor_id', drop=False), on='stor_id', rsuffix='_discount')
    [['stor_id_discount', 'discount', 'stor_id', 'stor_name' ]]
)
# Out:
#    stor_id_discount  discount  stor_id                             stor_name
# 0               NaN       NaN     6380                   Eric the Read Books
# 1               NaN       NaN     7066                              Barnum's
# 2               NaN       NaN     7067                          News & Brews
# 3               NaN       NaN     7131  Doc-U-Mat: Quality Laundry and Books
# 4               NaN       NaN     7896                    Fricative Bookshop
# 5            8042.0       5.0     8042                              Bookbeat

# %%
(
    stores.merge(discounts, on='stor_id', how='left', indicator=True)
    [[ 'stor_id_discount', 'discount', 'stor_id', 'stor_name' ]]
)
# Out:
#    stor_id                             stor_name         stor_address  \
# 0     6380                   Eric the Read Books  788 Catamaugus Ave.
# 1     7066                              Barnum's    567 Pasadena Ave.
# 2     7067                          News & Brews        577 First St.
# 3     7131  Doc-U-Mat: Quality Laundry and Books    24-A Avogadro Way
# 4     7896                    Fricative Bookshop       89 Madison St.
# 5     8042                              Bookbeat       679 Carson St.
#
#         city state    zip       discounttype  lowqty  highqty  discount  \
# 0    Seattle    WA  98056                NaN     NaN      NaN       NaN
# 1     Tustin    CA  92789                NaN     NaN      NaN       NaN
# 2  Los Gatos    CA  96745                NaN     NaN      NaN       NaN
# 3   Remulade    WA  98014                NaN     NaN      NaN       NaN
# 4    Fremont    CA  90019                NaN     NaN      NaN       NaN
# 5   Portland    OR  89076  Customer Discount     0.0      0.0       5.0
#
#       _merge
# 0  left_only
# 1  left_only
# 2  left_only
# 3  left_only
# 4  left_only
# 5       both

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# SELECT d.stor_id AS disstor, d.discount, s.stor_id AS storid, s.stor_name
# FROM discounts AS d
# RIGHT JOIN stores AS s
# ON d.stor_id=s.stor_id;
#
# ```

# %% [markdown]
# ## 11.&nbsp;Select all store names and the discounts they offer.
#
#        - This time, we don't want do display stores that don't offer any
#          discount.
#
#     Hint: change the join type!

# %%
(
    stores.join(
        discounts.set_index('stor_id'), on='stor_id', how='inner')
    [['stor_name', 'stor_id', 'discount']]
)
# Out:
#   stor_name  stor_id  discount
# 5  Bookbeat     8042       5.0

# %% [markdown]
# ### Hint:

# %% [markdown]
# In SQL the syntax is:
#
# ```sql
# select St.stor_name,St.stor_id ,D.discount
# from  stores St
# inner join discounts  D on St.stor_id=D.stor_id ;
# ```
