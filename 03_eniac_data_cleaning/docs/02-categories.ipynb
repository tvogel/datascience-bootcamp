# %% [markdown]
# # Chapter 3: Eniac Data Cleaning (Categories)
# ## Import

# %%
import os
os.chdir(os.path.join('..', 'data'))
tables_csv = [ csv for csv in os.listdir() if csv.endswith('.csv') ]

# %%
import pandas as pd
tables = {}
for table_csv in tables_csv:
    varname = table_csv.removesuffix('.csv')
    print(f'Reading {table_csv} into {varname} and {varname}_orig')
    tables[varname] = pd.read_csv(table_csv)
    tables[f'{varname}_orig'] = tables[varname].copy()

locals().update(tables)
# Out:
# Reading brands.csv into brands and brands_orig
# Reading orderlines.csv into orderlines and orderlines_orig
# Reading orderlines_cl.csv into orderlines_cl and orderlines_cl_orig
# Reading orders.csv into orders and orders_orig
# Reading orders_cl.csv into orders_cl and orders_cl_orig
# Reading products.csv into products and products_orig
# Reading products_cl.csv into products_cl and products_cl_orig
# Reading type_to_name.csv into type_to_name and type_to_name_orig
# Reading type_to_name_empty.csv into type_to_name_empty and type_to_name_empty_orig

# %% [markdown]
# ## Config

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: f'{x:.2f}')
pd.set_option('display.max_colwidth', 250)

# %% [markdown]
# ## Make `products.price` useful

# %%
THREEDIGITS=r'.*\.\d\d\d'
products = (
    products
    .assign(price=lambda x: x.price.fillna(''))
    .assign(price=lambda x: x.price.where(
        ~x.price.str.fullmatch(THREEDIGITS),
        ''))
    .assign(price=lambda x: pd.to_numeric(x.price))
)

# %% [markdown]
# ## Word statistics by `products.type`

# %%
products_word_statistics = (
    products
    # join `name` and `desc`
    .assign(words=lambda x: (x.name + ' ' + x.desc).str.lower())
    # make sure "for" stays with the next word
    .assign(words=lambda x: x.words.str.replace('for ', 'for_'))
    # keep fixed phrase together
    .assign(words=lambda x: x.words.str.replace(
        'including parts and labor',
        'including_parts_and_labor'))
    # fixup misformatting
    .assign(words=lambda x: x.words.str.replace(' "', '" '))
    # split the words into a list
    .assign(words=lambda x: x.words.str.split())
    # collect all words for each type into (huge) lists and count products
    .groupby('type')
    .agg(count = ('type','count'), avg_price=('price', 'mean'), words = ('words', 'sum'))
    # now make separate rows for each word, so we can make statistics
    .explode('words')
    # remove words that are not useful in statistics
    [lambda x: ~x.words.isin([
        'and',
        'with',
        'of',
        'including',
        'for',
        'your',
        'to',
        '-',
        '/',
        '+',
        '|',
      ])]
    # canonify words
    .assign(words=lambda x:x.words.replace({
        'wi-fi': 'wifi'
    }))
    # count statistics of each word within each type
    # also group by `count` as it is unique for each type and such that
    # the aggregation is not done on it
    .groupby(['type', 'count', 'avg_price'])
    .value_counts()
    # name the counts `freq`
    .rename('freq')
    # make the new `words` index an ordinary column again
    .reset_index('words')
    # select at most top-ten most frequent words
    .groupby(['type', 'count', 'avg_price'])
    .head(10)
    # combine words and frequencies into a single column for display
    .assign(word_freqs=lambda x: x.words.map(str)+':'+x.freq.map(str))
    # collect all words/statistics into a single row per type
    .groupby(['type', 'count', 'avg_price'])
    .agg({'words': list, 'word_freqs': list})
    # make the `count` index an ordinary column again
    .reset_index(['count', 'avg_price'])
    .sort_values('count',ascending=False)
)

# %%
products_word_statistics = (
    products_word_statistics
    .join(
        orderlines
        [lambda x: x.id_order.isin(
            orders.query('state=="Completed"').order_id
        )]
        .join(products.set_index('sku'), on='sku')
        .groupby('type')
        .agg(sales_count=('product_quantity','sum')),
        on='type'
    )
)

# %%
products_word_statistics.insert(2,'name','')
products_word_statistics.sample(20)
# Out:
#           count  avg_price name  \
# type
# 5384        182     148.07
# 9094         58     272.29
# 12085400      6      27.99
# 12655397    107     193.92
# 85641716     33     797.54
# 1375          9     116.10
# 1416         24     353.39
# 24885185     68     540.79
# 11859         4      68.99
# 24215399     41      46.19
# 14035403     22      29.35
# 54864259      7      58.70
# 5,72E+15      6    1282.33
# 24811716     17     733.29
# 54085407     10      39.47
# 1296        188     512.68
# 5404         12     291.22
# 1216         67     119.79
# 8696         58      76.57
# 1230         74      26.40
#
#                                                                                                         words  \
# type
# 5384                 [headphones, ipad, headset, wireless, ipod, for_iphone, bluetooth, black, beats, iphone]
# 9094                                   [camera, arlo, surveillance, hd, netgear, 2, ipad, pro, night, vision]
# 12085400                        [cleaner, ipad, spray, ipod, spray., screens, mac, iphone, display, cleaning]
# 12655397                                         [hard, drive, pc, sata, 35", mac, nas, wd, digital, western]
# 85641716                                       [iphone, 7, apple, free, new, gold, black, 128gb, 256gb, 32gb]
# 1375         [microphone, usb, blue, microphones, for_mac, snowball, professional, connection, yeti, pattern]
# 1416                                  [adobe, for_mac, cc, software, pc., license, mac, update, office, home]
# 24885185                               [apple, watch, 38mm, strap, case, sport, series, aluminum, gps, steel]
# 11859     [sensor, homekit, fibaro, windows, window, multi-sensor, multi-function, movement, for_doors, door]
# 24215399                       [watch, charging, apple, for_apple, dock, stand, support, base, watch., cable]
# 14035403                                [protector, screen, ipad, for_ipad, air, mini, pro, 2, ivisor, moshi]
# 54864259                          [apple, remote, case, siri, tv, control, media, player, griffin, for_apple]
# 5,72E+15                                      [imac, ram, core, hdd, 4gb, i5, 1tb, hand, refurbished, second]
# 24811716                                  [6s, iphone, plus, apple, 32gb, new, gold, free, 16gb, refurbished]
# 54085407                               [pro, mid, macbook, ifixit, fan, bracket, for_macbook, 13, 13", cable]
# 1296                                               [monitor, hdmi, for_mac, pc, ips, 4k, dell, lg, benq, 99%]
# 5404                           [radar, personal, robot, camera, action, black, video, lamp, polaroid, elgato]
# 1216                    [support, ipad, security, pro, stand, black, for_ipad, adjustable, securityxtra, one]
# 8696                          [support, macbook, aluminum, pro, for_macbook, stand, imac, design, air, magic]
# 1230                             [cable, lightning, usb, ipad, ipod, iphone, for_iphone, apple, white, ipod.]
#
#                                                                                                                              word_freqs  \
# type
# 5384      [headphones:183, ipad:137, headset:123, wireless:122, ipod:116, for_iphone:114, bluetooth:113, black:57, beats:56, iphone:46]
# 9094                               [camera:85, arlo:45, surveillance:41, hd:39, netgear:37, 2:33, ipad:33, pro:29, night:27, vision:26]
# 12085400                              [cleaner:3, ipad:3, spray:3, ipod:2, spray.:2, screens:2, mac:2, iphone:2, display:2, cleaning:2]
# 12655397                                   [hard:163, drive:138, pc:94, sata:85, 35":65, mac:63, nas:57, wd:56, digital:53, western:53]
# 85641716                                   [iphone:66, 7:66, apple:64, free:32, new:31, gold:24, black:24, 128gb:24, 256gb:21, 32gb:20]
# 1375            [microphone:18, usb:14, blue:10, microphones:9, for_mac:9, snowball:5, professional:5, connection:5, yeti:4, pattern:4]
# 1416                                  [adobe:21, for_mac:19, cc:18, software:15, pc.:11, license:11, mac:9, update:8, office:8, home:8]
# 24885185                         [apple:136, watch:136, 38mm:93, strap:65, case:62, sport:59, series:56, aluminum:47, gps:47, steel:34]
# 11859           [sensor:7, homekit:7, fibaro:5, windows:2, window:2, multi-sensor:2, multi-function:2, movement:2, for_doors:2, door:2]
# 24215399                   [watch:66, charging:49, apple:48, for_apple:34, dock:23, stand:23, support:17, base:16, watch.:15, cable:14]
# 14035403                               [protector:32, screen:31, ipad:26, for_ipad:16, air:16, mini:11, pro:10, 2:9, ivisor:8, moshi:8]
# 54864259                              [apple:12, remote:11, case:6, siri:6, tv:5, control:4, media:4, player:4, griffin:3, for_apple:3]
# 5,72E+15                                       [imac:12, ram:12, core:12, hdd:12, 4gb:10, i5:8, 1tb:6, hand:6, refurbished:6, second:6]
# 24811716                              [6s:34, iphone:34, plus:34, apple:30, 32gb:18, new:15, gold:13, free:12, 16gb:10, refurbished:10]
# 54085407                                  [pro:17, mid:15, macbook:11, ifixit:9, fan:8, bracket:8, for_macbook:7, 13:6, 13":6, cable:6]
# 1296                                        [monitor:354, hdmi:118, for_mac:111, pc:97, ips:64, 4k:62, dell:59, lg:58, benq:57, 99%:55]
# 5404                                 [radar:6, personal:6, robot:6, camera:6, action:5, black:5, video:4, lamp:4, polaroid:4, elgato:3]
# 1216                [support:81, ipad:77, security:29, pro:27, stand:26, black:26, for_ipad:23, adjustable:23, securityxtra:22, one:20]
# 8696                      [support:75, macbook:58, aluminum:35, pro:28, for_macbook:21, stand:16, imac:15, design:15, air:13, magic:13]
# 1230                      [cable:120, lightning:118, usb:102, ipad:56, ipod:46, iphone:41, for_iphone:30, apple:26, white:24, ipod.:20]
#
#           sales_count
# type
# 5384          2644.00
# 9094           201.00
# 12085400        46.00
# 12655397      2985.00
# 85641716       328.00
# 1375            47.00
# 1416            56.00
# 24885185       170.00
# 11859           25.00
# 24215399       288.00
# 14035403        80.00
# 54864259        29.00
# 5,72E+15         7.00
# 24811716        51.00
# 54085407        55.00
# 1296          1903.00
# 5404            40.00
# 1216            86.00
# 8696           540.00
# 1230          2015.00

# %%
products_word_statistics.to_csv('type_to_name_empty.csv')

# %% [markdown]
# ## Specific types

# %%
products.query('type == "5,74E+15"').sample(10)
# Out:
#           sku  \
# 5226  PAC1048
# 6443  PAC1069
# 3877  APP1383
# 6856  PAC1608
# 7519  PAC1620
# 4362  PAC1033
# 3590  APP1378
# 9868  PAC0974
# 3445  APP1376
# 5676  PAC1056
#
#                                                                                     name  \
# 5226                          Apple iMac 27 "Core i5 3.3GHz Retina 5K | 16GB | 1TB Flash
# 6443              Apple iMac 27 "Core i7 Retina 5K 4Hz | 16GB | 1TB Flash | R9 M395X 4GB
# 3877           Apple iMac 27 "Core i5 3.3GHz Retina 5K | 8GB | 2TB Fusion | R9 M395X 4GB
# 6856                        Apple iMac 27 "Core i5 3.3GHz Retina 5K | 16GB RAM | 1TB SSD
# 7519  Apple iMac 27 "Core i5 3.3GHz Retina 5K | 16GB RAM | 1TB SSD | Radeon R9 M395X 4GB
# 4362                           Apple iMac 27 "Core i7 Retina 5K 4GHz | 16GB | 2TB Fusion
# 3590                           Apple iMac 27 "Core i7 Retina 5K 4GHz | 8GB | 256GB Flash
# 9868                        Apple iMac 27 "Core i5 3.2GHz Retina 5K | 32GB | 256GB Flash
# 3445                            Apple iMac 27 "Core i7 Retina 5K 4GHz | 8GB | 3TB Fusion
# 5676          Apple iMac 27 "Core i5 3.3GHz Retina 5K | 16GB | 3TB Fusion | R9 M395X 4GB
#
#                                                                                                          desc  \
# 5226                       IMac desktop computer 27 inch 5K Retina i5 3.3GHz 16GB Flash RAM 1TB (MK482Y / A).
# 6443          IMac desktop computer 27 inch 5K Retina i5 3.3GHz RAM 16GB 1TB Flash R9 M395X 4GB (MK482Y / A).
# 3877                                 IMac desktop computer 27 inch 8GB RAM 2TB 5K Retina Fusion (MK482Y / A).
# 6856  Desktop computer iMac 27-inch 3.3GHz Core i5 5K Retina | 16GB RAM | 1TB SSD | R9 M395X 4GB (MK482Y / A)
# 7519  Desktop computer iMac 27-inch 3.3GHz Core i5 5K Retina | 16GB RAM | 1TB SSD | R9 M395X 4GB (MK482Y / A)
# 4362                        IMac desktop computer 27 inch 5K Retina 4GHz i7 RAM 16GB 2TB Fusion (MK482Y / A).
# 3590                                IMac desktop computer 27 inch 8GB RAM 256GB Retina 5K Flash (MK482Y / A).
# 9868                     IMac desktop computer 27 inch 5K Retina i5 3.2GHz 256GB Flash RAM 32GB (MK472Y / A).
# 3445                                 IMac desktop computer 27 inch 5K Retina 8GB RAM 3TB Fusion (MK482Y / A).
# 5676         IMac desktop computer 27 inch 5K Retina i5 3.3GHz RAM 16GB 3TB Fusion R9 M395X 4GB (MK482Y / A).
#
#        price promo_price  in_stock      type
# 5226 3589.00  32.739.902         0  5,74E+15
# 6443 4189.00  38.449.904         0  5,74E+15
# 3877 2929.00  27.895.848         0  5,74E+15
# 6856 3589.00  29.859.896         0  5,74E+15
# 7519 3889.00  32.959.904         0  5,74E+15
# 4362 3169.00  28.739.896         0  5,74E+15
# 3590 2929.00  27.895.848         0  5,74E+15
# 9868 3169.00  26.309.901         0  5,74E+15
# 3445 3049.00   2.903.585         0  5,74E+15
# 5676 3289.00  29.889.904         0  5,74E+15

# %% [markdown]
# ## Assigned category names

# %%
type_to_name
# Out:
#           type                  name
# 0     5,74E+15               imac_5k
# 1     1,02E+12            macbook_i5
# 2         1282                  imac
# 3     11935397        ext_hard_drive
# 4         2158            macbook_i7
# 5     12175397                   nas
# 6     2,17E+11            macbook_13
# 7     12215397           ssd_kit_air
# 8         1296               monitor
# 9         1405       graphics_tablet
# 10        1364           desktop_ram
# 11    2,16E+11                imac_2
# 12    12655397         pc_hard_drive
# 13    11905404               gadgets
# 14   113271716              iphone_x
# 15        5384             headphone
# 16    51601716                iphone
# 17        1433          ssd_kit_mini
# 18   113281716         iphone_8_plus
# 19   113291716              iphone_8
# 20    85641716              iphone_7
# 21    12995397      thunderbolt_dock
# 22        1714                  ipad
# 23    24895185        apple_watch_42
# 24    85651716         iphone_7_plus
# 25   106431714              ipad_pro
# 26        1231             applecare
# 27    21561716              iphone_6
# 28    11865403           iphone_case
# 29    12585395           usb_adapter
# 30        5398     bluetooth_speaker
# 31    21632158           mac_pro_ram
# 32        1298           refurbished
# 33    5,39E+11            macbook_12
# 34   118692158              imac_pro
# 35       10142       macbook_battery
# 36    24885185        apple_watch_38
# 37    42945397    lightning_pendrive
# 38    51861714           ipad_pro_12
# 39    24821716             iphone_6s
# 40    13855401              keyboard
# 41        1325             usb_cable
# 42    13005399       macbook_charger
# 43    12575403         ipad_keyboard
# 44        1334           wifi_router
# 45    12755395       ssd_adapter_kit
# 46        9094          surveillance
# 47    12635403       ipad_protection
# 48        1230       lightning_cable
# 49    51882158                imac_3
# 50    13835403    macbook_protection
# 51    57445397           memory_card
# 52    51871714            ipad_pro_9
# 53        1387                 mouse
# 54        1392      macbook_backpack
# 55        8696       macbook_support
# 56        1229           ipad_stylus
# 57    24811716        iphone_6s_plus
# 58    13615399        iphone_charger
# 59        1515     iphone_power_bank
# 60    5,43E+15      imac_refurbished
# 61    14305406             mac_tools
# 62    42931714              ipad_air
# 63        1404         nas_accessory
# 64    13555403     iphone_protection
# 65    13621714           ipad_mini_4
# 66    11821715            ipod_touch
# 67        5401    bluetooth_keyboard
# 68        1416              software
# 69    12141714            ipad_air_2
# 70        1276            pcie_esata
# 71   101781405       wacom_accessory
# 72        5395             usb_strip
# 73   113464259              apple_tv
# 74        2449     apple_watch_strap
# 75    12645406          iphone_tools
# 76        5399      wireless_charger
# 77    24215399   watch_charging_dock
# 78        4259  apple_tv_refurbished
# 79        5720        iphone_support
# 80       10230      macbook_pro_back
# 81        5404                   NaN
# 82    5,44E+11                   NaN
# 83        1280                   NaN
# 84    21485407          iphone_tools
# 85        1216          ipad_support
# 86        1424                   NaN
# 87    1,44E+11         iphone_repair
# 88    5,72E+15                   NaN
# 89    14365395                   NaN
# 90    5,49E+11   iphone_battery_case
# 91    24861714                   NaN
# 92        5403                   NaN
# 93        1375                   NaN
# 94    21571716                   NaN
# 95    12355400                   NaN
# 96    20642062                   NaN
# 97        2425                   NaN
# 98        2434                   NaN
# 99    51912158                   NaN
# 100       5405                   NaN
# 101   14035403                   NaN
# 102       1716                   NaN
# 103   12051714                   NaN
# 104   54085407                   NaN
# 105   5,45E+15                   NaN
# 106      11859                   NaN
# 107   54864259                   NaN
# 108   12085400                   NaN
# 109   12031714                   NaN
# 110  113851714                   NaN
# 111   21535407                   NaN
# 112   79201715                   NaN
# 113   13955395                   NaN
# 114   21622158                   NaN
# 115   54025401                   NaN
# 116   12285400                   NaN
# 117   15435404                   NaN
# 118       5407                   NaN
# 119      11434                   NaN
# 120       5406                   NaN
# 121   51902158                   NaN
# 122      12282                   NaN
# 123       5185                   NaN
# 124   9,29E+11                   NaN
