# %% [markdown]
# # Searching for the category

# %% [markdown]
# For this code along we are only going to use the products DataFrame. However, if you believe there is information in other tables that can help to create categories, please feel free to explore.

# %%
import pandas as pd

# %%
# products_cl.csv
url = "https://drive.google.com/file/d/1s7Lai4NSlsYjGEPg1QSOUJobNYVsZBOJ/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_cl = pd.read_csv(path)

# %%
product_category_df = products_cl.copy()

# %%
product_category_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price  in_stock  \
# 0       Aluminum support compatible with all MacBook  59.99         1
# 1          USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# 2                             mouse Apple USB cable.  59.00         0
# 3              IPhone dock and USB Cable Apple iPod.  25.00         0
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99         1
#
#        type
# 0      8696
# 1  13855401
# 2      1387
# 3      1230
# 4      1364

# %% [markdown]
# ## 1.&nbsp; Category creation by search term
# Let's start by creating a column `category`. For now we'll fill this column with a blank string `""`.

# %%
product_category_df["category"] = ""
product_category_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price  in_stock  \
# 0       Aluminum support compatible with all MacBook  59.99         1
# 1          USB ultrathin keyboard Apple Mac Spanish.  59.00         0
# 2                             mouse Apple USB cable.  59.00         0
# 3              IPhone dock and USB Cable Apple iPod.  25.00         0
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99         1
#
#        type category
# 0      8696
# 1  13855401
# 2      1387
# 3      1230
# 4      1364

# %% [markdown]
# We can find all the products with certain words in their `description` using `.loc[]` and `.str.contains()`. Here we'll look at all the items that have the word `keyboard` in their description.

# %%
product_category_df.loc[product_category_df["desc"].str.contains("keyboard", case=False)]
# Out:
#             sku                                               name  \
# 1       APP0023                  Apple Mac Keyboard Keypad Spanish
# 15      MOS0021               Clearguard Moshi MacBook Pro and Air
# 24      APP0277         Apple Wireless Keyboard Keyboard (OEM) Mac
# 64      HGD0012            Henge Docks Click keyboard support iMac
# 365     LOG0084  Logitech Ultrathin Keyboard Cover Keyboard Cov...
# ...         ...                                                ...
# 9720    PAC2508  Replacement Magic Wireless Keyboard by Matias ...
# 9751    MTF0008               Mistify Clean Screens Natural 500ml.
# 9796  ZAG0026-A  Open - Zagg Rugged Keyboard Folio iPad Messeng...
# 9932    APP1472         Apple Magic Keyboard English International
# 9945  TWS0106-A  Open - Twelve South Bridge Magic Keyboard for ...
#
#                                                    desc   price  in_stock  \
# 1             USB ultrathin keyboard Apple Mac Spanish.   59.00         0
# 15    Keyboard Protector MacBook Pro 13-inch Retina ...   24.95         0
# 24    Ultrathin keyboard Apple Bluetooth Spanish (un...   79.00         0
# 64    Base to hold the Apple Magic TrackPad and Wire...   29.00         0
# 365   Ultrathin cover and cover with Bluetooth keybo...   89.99         0
# ...                                                 ...     ...       ...
# 9720  Keyboard replacement service at the time of pu...  119.99         1
# 9751              Spray cleaning screens and keyboards.   14.99         1
# 9796  Case reconditioned keyboard and adjustable pos...   99.99         0
# 9932  English keyboard Mac and Apple iPad Ultrathin ...  119.00         1
# 9945  Light reconditioned support to hold the Keyboa...   48.00         0
#
#           type category
# 1     13855401
# 15    13835403
# 24    13855401
# 64        8696
# 365   12575403
# ...        ...      ...
# 9720  13855401
# 9751  12085400
# 9796  12575403
# 9932  13855401
# 9945      8696
#
# [89 rows x 7 columns]

# %% [markdown]
# Next, we change the value in the category column to `keyboard` for all of these keyboard products.

# %%
product_category_df.loc[product_category_df["desc"].str.contains("keyboard", case=False), "category"] = "keyboard"

# %% [markdown]
# Let's take a look at the effect that had on the `category` column.

# %%
product_category_df["category"].value_counts()
# Out:
#             9903
# keyboard      89
# Name: category, dtype: int64

# %% [markdown]
# ## 2.&nbsp; Category creation using regex
# We can also use a product's `name` to select products for our categories.

# %%
product_category_df.loc[product_category_df["name"].str.contains("apple iphone", case=False)]
# Out:
#             sku                                               name  \
# 35      APP0308  AV Cable Adapter Apple iPhone iPad and iPod white
# 214     REP0100               Color change to White Apple iPhone 4
# 215     REP0052               Color change to White Apple iPhone 4
# 579     APP0675                    Apple iPhone 5S 32GB Space Gray
# 956     APP0823                         Apple iPhone 6 16GB Silver
# ...         ...                                                ...
# 9790    AP20455               Like new - Apple iPhone 8 256GB Gold
# 9794  APP2482-A              Open - Apple iPhone 8 Plus 256GB Gold
# 9929  APP2477-A         Open - Apple iPhone 8 Plus 64GB Space Gray
# 9958    AP20467  Like new - Apple iPhone Silicone Case Cover 7 ...
# 9969    AP20468       Like new - Apple iPhone Black Lightning Dock
#
#                                                    desc    price  in_stock  \
# 35               IPhone iPad iPod adapter and AV cable.    45.00         0
# 214                   It is including parts and labor..    94.21         0
# 215                   It is including parts and labor..    94.21         0
# 579               New Free iPhone 5S 32GB (ME435Y / A).   559.00         0
# 956               New iPhone 6 16GB Free (MG482QL / A).   639.00         0
# ...                                                 ...      ...       ...
# 9790  Apple iPhone 8 reconditioned 256GB in Gold rea...   979.00         0
# 9794    Refurbished Apple iPhone 8 Plus 256GB Free Gold  1089.00         0
# 9929                Apple iPhone 8 Plus 64GB Space Gray   919.00         0
# 9958  Reconditioned silicone sleeve microfiber Apple...    45.00         0
# 9969  Support base and refitted with dock connector ...    59.00         0
#
#            type category
# 35         1230
# 214    1,44E+11
# 215    1,44E+11
# 579         NaN
# 956         NaN
# ...         ...      ...
# 9790  113291716
# 9794  113281716
# 9929  113281716
# 9958   11865403
# 9969   13615399
#
# [424 rows x 7 columns]

# %% [markdown]
# Looks like we get a lot of accessories included in this search. We can refine this using a little regex. Here, we will add `.{0,7}` at the beginning of the search: this means we will find all `apple iphone`s that have 7 or less characters preceding the term "apple iphone" - if there's 8 characters preceding the search term, it won't be found. This should help refine our search by using the nomenclature of the DataFrame to our advantage.
#
# If you feel unsure about regex, please use [regex101](https://regex101.com/). It's really useful for checking your code, and parts of other people's code that you're unsure about.

# %%
product_category_df.loc[product_category_df["name"].str.contains("^.{0,7}apple iphone", case=False)]
# Out:
#             sku                                        name  \
# 579     APP0675             Apple iPhone 5S 32GB Space Gray
# 956     APP0823                  Apple iPhone 6 16GB Silver
# 961     APP0829             Apple iPhone 6 Plus 16GB Silver
# 962     APP0822              Apple iPhone 6 16GB Space Gray
# 963     APP0825              Apple iPhone 6 64GB Space Gray
# ...         ...                                         ...
# 9585  APP1634-A       Open - Apple iPhone 7 Plus 32GB Black
# 9587  APP2540-A    Open - Apple iPhone Leather Folio X Baya
# 9714  APP2562-A  Open - Apple iPhone Leather Case Cover Red
# 9794  APP2482-A       Open - Apple iPhone 8 Plus 256GB Gold
# 9929  APP2477-A  Open - Apple iPhone 8 Plus 64GB Space Gray
#
#                                                    desc   price  in_stock  \
# 579               New Free iPhone 5S 32GB (ME435Y / A).   559.0         0
# 956               New iPhone 6 16GB Free (MG482QL / A).   639.0         0
# 961           New iPhone 6 Plus 16G Free (MGA92QL / A).   749.0         0
# 962               New iPhone 6 16GB Free (MG472QL / A).   639.0         0
# 963               New iPhone 6 64GB Free (MG4F2QL / A).   749.0         0
# ...                                                 ...     ...       ...
# 9585            New 32GB Apple iPhone 7 Plus Free Black   779.0         0
# 9587     Leather case with box and official cover Apple   109.0         0
# 9714  Reconditioned skin sheath official Apple desig...    45.0         0
# 9794    Refurbished Apple iPhone 8 Plus 256GB Free Gold  1089.0         0
# 9929                Apple iPhone 8 Plus 64GB Space Gray   919.0         0
#
#            type category
# 579         NaN
# 956         NaN
# 961         NaN
# 962         NaN
# 963         NaN
# ...         ...      ...
# 9585   85651716
# 9587   11865403
# 9714   11865403
# 9794  113281716
# 9929  113281716
#
# [269 rows x 7 columns]

# %% [markdown]
# Now we can use the same trick as before to set the category - selecting the `category` column and setting it to the string of our choice.

# %%
product_category_df.loc[product_category_df["name"].str.contains("^.{0,7}apple iphone", case=False), "category"] = "smartphone"

# %%
product_category_df["category"].value_counts()
# Out:
#               9634
# smartphone     269
# keyboard        89
# Name: category, dtype: int64

# %% [markdown]
# ## 3.&nbsp; One product with multiple categories
# A product may fit into multiple categories. To help us create multiple categories for one product, we will use the python addition assignment `+=`. The addition assignment is a shorthand way to add something (number, string, etc...) to a variable without changing the variable name.
#
# Let's have a look at a couple of examples.

# %%
a = 10
a = a + 5
a
# Out:
# 15

# %%
a = 10
a += 5
a
# Out:
# 15

# %%
b = "Tyrannosaurus"
b = b + " rex"
b
# Out:
# 'Tyrannosaurus rex'

# %%
b = "Tyrannosaurus"
b += " rex"
b
# Out:
# 'Tyrannosaurus rex'

# %% [markdown]
# Now let's look at how this can help us in our category creation.
#
# First, we'll reset all the values in the category column to an empty string `""`.

# %%
product_category_df["category"] = ""

# %% [markdown]
# Now, let's create some categories and utilise the addition assignment.

# %%
product_category_df.loc[product_category_df["desc"].str.contains("keyboard", case=False), "category"] += ", keyboard"
product_category_df.loc[product_category_df["name"].str.contains("^.{0,7}apple iphone", case=False), "category"] += ", smartphone"
product_category_df.loc[product_category_df["name"].str.contains("^.{0,7}apple ipod", case=False), "category"] += ", ipod"
product_category_df.loc[product_category_df["name"].str.contains("^.{0,7}apple ipad|tablet", case=False), "category"] += ", tablet"
product_category_df.loc[product_category_df["name"].str.contains("imac|mac mini|mac pro", case=False), "category"] += ", desktop"

# %%
product_category_df["category"].value_counts()
# Out:
#                        8362
# , desktop               923
# , tablet                307
# , smartphone            269
# , keyboard               83
# , ipod                   42
# , keyboard, tablet        4
# , keyboard, desktop       2
# Name: category, dtype: int64

# %% [markdown]
# As you can see, some products now have 2 categories instead of just one. At the end, you can use your skills with string to tidy up the opening comma and space in the `category` column.

# %% [markdown]
# # Challenge. Your categories
# Now it's your turn. We'll reset the Dataframe so that no categories exist, and it's up to you to create the categories based on keywords in the name and description. Feel free to go wild and make as many categories as you like.
# * Remember you can also use regex to refine your searches.
# * Remember you can use the or operator `|` to search for multiple terms at once.
# * Remember to tidy up any untidy strings at the end.

# %%
# products_cl.csv
url = "https://drive.google.com/file/d/1s7Lai4NSlsYjGEPg1QSOUJobNYVsZBOJ/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products_cl = pd.read_csv(path)

product_category_df = products_cl.copy()

# %%
# your code here

# %% [markdown]
# ## 4.&nbsp; [BONUS] Using `type` to create categories
# There could be another way to create categories, but this one you'll have to explore this one alone.
#
# We have the mysterious column `type` in the `products` table. This could potentially be ready-made categories labelled with numbers instead of words. Let's investigate.

# %%
category_type_df = products_cl.copy()

# %% [markdown]
# Here are the `type`s that have the most products.

# %%
category_type_df.groupby("type").count().nlargest(10, "sku")
# Out:
#            sku  name  desc  price  in_stock
# type
# 11865403  1057  1057  1057   1057      1057
# 12175397   939   939   939    939       939
# 1298       783   783   783    783       783
# 11935397   562   562   562    562       562
# 11905404   454   454   454    454       454
# 1282       373   373   373    373       373
# 12635403   362   362   362    362       362
# 13835403   269   269   269    269       269
# 5,74E+15   247   247   247    247       247
# 1364       216   216   216    216       216

# %% [markdown]
# Let's have a look at the first `type` to see if we can make categories from this column.

# %%
category_type_df.loc[category_type_df["type"] == "11865403"].sample(10)
# Out:
#           sku                                               name  \
# 2546  APP1135  Case Apple iPhone 6 / 6S Candy Brown Leather Case
# 8245  SPE0206  Presidio Speck Case iPhone 8/7 / 6s / 6 Transp...
# 1022  TUC0180             Tucano Fabric Case iPhone 6 Plus Coral
# 1390  TCH0009  Tech21 Classic Frame iPhone 6 Plus Case Smokey...
# 5022  MUJ0014  Mujjo Leather Wallet Leather Case iPhone 8/7 Gray
# 5075  PUR0149  Puro iPhone Wallet Case Card Holder 8 Plus / 7...
# 5188  OTT0155          OtterBox iPhone Case Etui Symmetry 7 Rosa
# 4524  OTT0132  OtterBox Symmetry Alpha Glass Case + Screen Pr...
# 1313  TWS0075   Twelve South SurfacePad Case iPhone 6 / 6S White
# 3083  MOS0173  Moshi iGlaze Case Napa iPhone 6 / 6S Plus Red ...
#
#                                                    desc  price  in_stock  \
# 2546  ultrathin leather case and microfiber premium ...  55.00         0
# 8245  Protective cover with anti-impact polycarbonat...  24.95         0
# 1022  Cover for iPhone 6 Plus ultra light polycarbon...  14.90         0
# 1390  ultra durable and anti-shock technology D3O fo...  34.99         0
# 5022  ultrathin cover with card case and material ve...  39.90         0
# 5075  Resistant cover with magnetic closure wallet c...  16.95         0
# 5188  Card slot cover and protective cover for iPhone 7  39.99         0
# 4524  Pack OtterBox Symmetry Case + Screen Protector...  49.99         0
# 1313   Lockable card case cover for iPhone 6 type book.  49.99         0
# 3083  Housing double protective coating for iPhone 6...  50.00         0
#
#           type
# 2546  11865403
# 8245  11865403
# 1022  11865403
# 1390  11865403
# 5022  11865403
# 5075  11865403
# 5188  11865403
# 4524  11865403
# 1313  11865403
# 3083  11865403

# %% [markdown]
# Looks like this is a category of phone cases.
#
# Let's have a look at the 2nd largest type to see if that's also a clear category.

# %%
category_type_df.loc[category_type_df["type"] == "12175397"].sample(10)
# Out:
#           sku  \
# 6020  PAC1705
# 1079  PAC0517
# 9362  PAC2491
# 8522  PAC2378
# 8835  PAC2302
# 3896  PAC1365
# 3225  PAC1313
# 9352  PAC2481
# 5026  SYN0152
# 4755  QNA0172
#
#                                                                       name  \
# 6020     Pack QNAP TS-451A NAS server 2GB l l 8TB (4x2TB) Seagate IronWolf
# 1079                           Synology DS115j Pack + 3TB Seagate IronWolf
# 9362                       Synology DS218 NAS Server | 16TB (2x8TB) WD Red
# 8522  Synology DS418 NAS Server | 2GB RAM | 12TB (4x3TB) Seagate Iron Wolf
# 8835                        Synology DS118 NAS Server | 6TB (1x6TB) WD Red
# 3896                               Synology DS216 + Pack | WD 12TB Network
# 3225                        Pack QNAP TS-451 + | 8GB RAM | WD 24TB Network
# 9352             Synology DS218 NAS Server | 6TB (2x3TB) Seagate Iron Wolf
# 5026                                   Synology RackStation NAS RS3617RPxs
# 4755        QNAP TVS-1282T i5 16GB Ram 2 Server NAS Thunderbolt Mac and PC
#
#                                                                                                 desc  \
# 6020                    Nas TS-451A with 2GB of RAM and 8 TB (4x2TB) Seagate IronWolf for Mac and PC
# 1079                                          Synology DS115j NAS Server Pack + 3TB Seagate IronWolf
# 9362                                              2-bay NAS server can accommodate 4K Ultra HD files
# 8522                    NAS server 4 bays and 2GB of RAM DDR4 capable of transmitting H.265 video 4K
# 8835                                 1 bay NAS server with capacity for home use or small businesses
# 3896                                                   NAS + 12TB (2x6TB) WD Network for Mac and PC.
# 3225  Pack QNAP TS-451 + with 8GB of RAM memory + 24TB (4x6TB) Network WD Hard Drive for Mac and PC.
# 9352                                              2-bay NAS server can accommodate 4K Ultra HD files
# 5026                                          12-bay NAS server Enterprise 8GB memory for Mac and PC
# 4755                           NAS 12 bays 2 2 3 HDMI ports Thunderbolt 16GB DDR4 RAM for Mac and PC
#
#         price  in_stock      type
# 6020   886.95         0  12175397
# 1079   231.98         0  12175397
# 9362   991.46         1  12175397
# 8522   984.95         0  12175397
# 8835   430.99         0  12175397
# 3896   930.99         0  12175397
# 3225  1619.99         0  12175397
# 9352   553.44         0  12175397
# 5026  3392.73         0  12175397
# 4755  3205.29         0  12175397

# %% [markdown]
# Looks like this category is full of servers.
#
# I wonder how many `type`s account for most of our products?

# %%
n = 30
print(f"With the {n} largest types, we account for {((category_type_df.groupby('type').count().nlargest(n, 'sku')['sku'].sum()) / (category_type_df.shape[0]) * 100).round(2)}% of all products.")
# Out:
# With the 30 largest types, we account for 78.4% of all products.

# %% [markdown]
# Looks like we can simply investigate 30 types and set the categories, then the remaining 20% of products can have the category `other`.
#
# Use the skills you learnt above to change the category for each type.

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_colwidth', 250)
(
    category_type_df
    # join `name` and `desc`
    .assign(words=lambda x: (x.name + ' ' + x.desc).str.lower())
    # make sure "for" stays with the next word
    .assign(words=lambda x: x.words.str.replace('for ', 'for_'))
    # keep fixed phrase together
    .assign(words=lambda x: x.words.str.replace(
        'including parts and labor',
        'including_parts_and_labor'))
    # fixup misformatting
    .assign(words=lambda x: x.words.str.replace(' "', '" '))
    # split the words into a list
    .assign(words=lambda x: x.words.str.split())
    # collect all words for each type into (huge) lists and count products
    .groupby('type')
    .agg(count = ('type','count'), words = ('words', 'sum'))
    # now make separate rows for each word, so we can make statistics
    .explode('words')
    # remove words that are not useful in statistics
    [lambda x: ~x.words.isin([
        'and',
        'with',
        'of',
        'including',
        'for',
        'your',
        'to',
        '-',
        '/',
        '+',
        '|',
      ])]
    # count statistics of each word within each type
    # also group by `count` as it is unique for each type and such that
    # the aggregation is not done on it
    .groupby(['type', 'count'])
    .value_counts()
    # name the counts `freq`
    .rename('freq')
    # make the new `words` index an ordinary column again
    .reset_index('words')
    # select at most top-ten most frequent words
    .groupby(['type', 'count'])
    .head(10)
    # combine words and frequencies into a single column for display
    .assign(word_freqs=lambda x: x.words.map(str)+':'+x.freq.map(str))
    # collect all words/statistics into a single row per type
    .groupby(['type', 'count'])
    .agg({'words': list, 'word_freqs': list})
    # make the `count` index an ordinary column again
    .reset_index('count')
)
# Out:
#            count  \
# type
# 1,02E+12     130
# 1,44E+11     129
# 10142         23
# 101781405     10
# 10230         29
# 106431714     29
# 113271716      4
# 113281716     16
# 113291716     13
# 113464259      1
# 113851714      2
# 11434          1
# 11821715      58
# 11859          2
# 11865403    1057
# 118692158     72
# 11905404     454
# 11935397     562
# 12031714       5
# 12051714       3
# 12085400       6
# 12141714      32
# 1216          67
# 12175397     939
# 12215397     170
# 12282          1
# 12285400       6
# 1229         104
# 1230          73
# 1231          10
# 12355400      27
# 12575403      22
# 12585395     190
# 12635403     362
# 12645406      43
# 12655397     105
# 12755395      29
# 1276          18
# 1280           5
# 1282         373
# 1296         187
# 1298         783
# 12995397      95
# 13005399      37
# 1325         183
# 1334         115
# 13555403      75
# 13615399      78
# 13621714      19
# 1364         216
# 1375           9
# 13835403     269
# 13855401      34
# 1387          23
# 1392          65
# 13955395       4
# 14035403      22
# 1404          31
# 1405          75
# 1416          24
# 1424          10
# 14305406      39
# 1433         171
# 14365395      21
# 1515          85
# 15435404       5
# 1714          28
# 1716          24
# 2,16E+11      42
# 2,17E+11      36
# 20642062       9
# 21485407      66
# 21535407      14
# 21561716       5
# 21571716       5
# 2158         107
# 21622158       1
# 21632158      37
# 24215399      41
# 2425           5
# 2434          26
# 2449         107
# 24811716      17
# 24821716      20
# 24861714       7
# 24885185      67
# 24895185      67
# 4259           6
# 42931714       8
# 42945397      44
# 5,39E+11      47
# 5,43E+15      14
# 5,44E+11       5
# 5,45E+15       1
# 5,49E+11      45
# 5,72E+15       6
# 5,74E+15     247
# 51601716      43
# 5185           1
# 51861714      28
# 51871714      15
# 51882158      10
# 51902158       1
# 51912158       1
# 5384         178
# 5395          31
# 5398         159
# 5399          14
# 5401           5
# 54025401       3
# 5403          19
# 5404          12
# 5405          39
# 5406           2
# 5407           3
# 54085407      10
# 54864259       7
# 5720          40
# 57445397     129
# 79201715       3
# 85641716      32
# 85651716      42
# 8696          57
# 9,29E+11       1
# 9094          50
#
#                                                                                                               words  \
# type
# 1,02E+12                                                 [pro, macbook, ssd, core, touch, bar, 16gb, i7, ram, pcie]
# 1,44E+11          [repair, service, including_parts_and_labor, iphone, for_iphone, for_ipad, ipad, 2, screen, mini]
# 10142                                   [battery, macbook, pro, nupower, newertech, late, 13", air, early, unibody]
# 101781405                        [wacom, intuos, cintiq, tips, replacement, kit, 4, accessory, graphics, for_wacom]
# 10230                                                [macbook, pro, retina, black, case, tucano, bag, 15, 15", 13"]
# 106431714                                       [pro, ipad, wi-fi, apple, cellular, new, 10.5", 64gb, 256gb, 512gb]
# 113271716                                       [iphone, x, 64gb, new, gray, free, space, apple, refurbished, like]
# 113281716                                            [iphone, plus, apple, 8, 64gb, space, 256gb, gray, gold, free]
# 113291716                                          [apple, iphone, 8, 64gb, gold, 256gb, silver, free, gray, space]
# 113464259                                                      [open, apple, multimedia, player, tv, box, 4k, 32gb]
# 113851714                                      [ipad, wi-fi, apple, gray, 32gb, 128gb, silver, space, (mp2h2ty, a)]
# 11434                                  [pro, adapter, security, (end, 2013)., apple, cable, for_mac, for_the, lock]
# 11821715                                [ipod, touch, apple, 16gb, generation, new, nano, player, music, megapixel]
# 11859      [homekit, fibaro, sensor, multi-sensor, movement, compatible, temperature, water, multi-function, flood]
# 11865403                                          [case, iphone, 6, plus, for_iphone, 6s, 7, cover, black, leather]
# 118692158                                         [pro, xeon, imac, w, intel, processor, vega, ssd, screen, retina]
# 11905404                          [ipad, for_iphone, iphone, ipod, bluetooth, white, control, app, black, activity]
# 11935397                              [hard, drive, usb, 3.0, external, for_mac, pc, thunderbolt, raid, connection]
# 12031714                                             [mini, 2, ipad, apple, space, 32gb, gray, wi-fi, 16gb, silver]
# 12051714                    [air, ipad, wi-fi, 16gb, apple, gray, repair, silver, space, including_parts_and_labor]
# 12085400                             [cleaner, ipad, spray, iphone, ipod, mac, screens, spray., display, bluetooth]
# 12141714                                               [ipad, wi-fi, apple, cellular, pro, air, 2, new, 9.7", 32gb]
# 1216                       [support, ipad, security, pro, stand, black, for_ipad, adjustable, securityxtra, iphone]
# 12175397                                         [nas, server, ram, synology, seagate, wd, for_mac, pack, pc, qnap]
# 12215397                                           [ssd, pro, kit, owc, expansion, macbook, air, sata, hard, 240gb]
# 12282                            [watch, compact, black, belkin, apple, support, stand, portable, or, horizontally]
# 12285400                                [ipad, iphone, cable, ipod, ipod., black, bluelounge, cabledrop, gloves, 6]
# 1229                                    [pointer, pen, stylus, digital, wacom, ipad, jot, adonit, bamboo, for_ipad]
# 1230                                  [cable, lightning, usb, ipad, ipod, iphone, for_iphone, apple, white, charge]
# 1231                              [warranty, extended, applecare, apple, protection, care, plan, macbook, pro, mac]
# 12355400                         [gopro, calibrator, usb, support, color, magic, adapter, battery, macbook, x-rite]
# 12575403                                         [keyboard, ipad, folio, air, cover, for_ipad, black, pro, 2, case]
# 12585395                                  [usb, adapter, usb-c, 3.0, hdmi, hub, for_mac, ethernet, thunderbolt, pc]
# 12635403                                             [ipad, case, pro, cover, mini, for_ipad, apple, air, smart, 4]
# 12645406                     [kit, ifixit, iphone, for_iphone, battery, tools, 5, screwdriver, change, replacement]
# 12655397                                               [hard, drive, pc, sata, 35", mac, nas, wd, digital, western]
# 12755395                                          [kit, adapter, ssd, owc, mac, pro, mini, bay, hard, installation]
# 1276                                                [card, pcie, sonnet, for_mac, esata, adapter, pro, s, ssd, 6gb]
# 1280                                   [expansion, nas, mac, pc, synology, server, unit, rackstation, module, mini]
# 1282                                                 [ram, apple, core, flash, i5, 8gb, imac, retina, macbook, pro]
# 1296                                                     [monitor, hdmi, for_mac, pc, ips, 4k, dell, lg, benq, 99%]
# 1298                                                 [open, pro, (open), usb, case, macbook, iphone, pc, hard, mac]
# 12995397                                            [thunderbolt, usb, external, 3.0, pc, 3, for_mac, dock, box, 2]
# 13005399                                 [charger, macbook, magsafe, air, apple, battery, pro, 2, for_macbook, mid]
# 1325                                        [cable, usb, thunderbolt, adapter, hdmi, usb-c, mini, belkin, 3, black]
# 1334                               [d-link, router, gigabit, wireless, wi-fi, switch, kit, wifi, adapter, ethernet]
# 13555403                               [6, iphone, glass, protector, plus, 6s, screen, for_iphone, tempered, saver]
# 13615399                           [charger, iphone, car, usb, lightning, belkin, charging, dock, for_iphone, base]
# 13621714                                           [apple, ipad, mini, 4, wi-fi, cellular, 16gb, 64gb, gray, space]
# 1364                                                    [mac, memory, ram, so-dimm, ddr3, pro, imac, owc, 8gb, 4gb]
# 1375         [microphone, usb, blue, microphones, for_mac, snowball, connection, professional, capsules, different]
# 13835403                                     [macbook, pro, case, air, 13", retina, for_macbook, black, sleeve, 13]
# 13855401                     [keyboard, mac, bluetooth, keypad, wireless, apple, spanish, ipad, ultrathin, for_mac]
# 1387                           [mouse, wireless, apple, for_mac, aluminum, trackpad, logitech, magic, 2, bluetooth]
# 1392                                     [backpack, macbook, pro, 15", 13", black, for_macbook, retina, air, thule]
# 13955395                             [connector, apple, ipad, sd, adapter, camera, cameras, card, connection, dock]
# 14035403                                      [protector, screen, ipad, for_ipad, air, mini, pro, 2, ivisor, moshi]
# 1404                                           [expansion, qnap, synology, nas, card, kit, rail, bays, ssd, memory]
# 1405                                         [tablet, graphics, wacom, pen, for_mac, pro, intuos, pc, black, touch]
# 1416                                        [adobe, for_mac, cc, software, pc., license, mac, update, office, home]
# 1424                                        [recorder, external, dvd, slim, ultra, pro, samsung, usb, video, white]
# 14305406                             [kit, ifixit, imac, macbook, pro, tool, tools, installation, ssd, screwdriver]
# 1433                                           [kit, ssd, expansion, pro, datadoubler, mini, imac, tools, ram, mid]
# 14365395                                [adapter, lightning, iphone, ipod, apple, 5, connector, for_iphone, car, 6]
# 1515                                  [battery, external, usb, for_iphone, mah, power, ipad, mophie, mirror, small]
# 15435404                            [for_mac, pro, fhd, controller, korg, littlebits, sensor, security, pc, motion]
# 1714                                                [ipad, wi-fi, apple, new, pro, cellular, 128gb, gold, 32gb, a)]
# 1716                                                          [apple, iphone, open, new, a), gb, 6s, like, free, 7]
# 2,16E+11                                                  [imac, 1tb, ram, ssd, core, apple, inch, 215, 21.5", 8gb]
# 2,17E+11                                                    [macbook, ram, 8gb, air, ssd, apple, i7, i5, core, 13"]
# 20642062                                   [installation, ssd, ram, macbook, pro, service, hdd, mac, in, transfer.]
# 21485407                                [iphone, piece, ifixit, for_iphone, 5, 5s, replacement, 6, battery, button]
# 21535407                                      [ipad, panel, front, for_ipad, ifixit, 2, 3/4, battery, white, tools]
# 21561716                                        [6, iphone, apple, space, gray, new, 16gb, 32gb, like, refurbished]
# 21571716                                       [apple, 6, plus, iphone, new, like, free, silver, refurbished, 16gb]
# 2158                                                     [pro, ssd, ram, pcie, macbook, core, bar, touch, 16gb, i7]
# 21622158                                                    [2, ram, mini, mac, hdd, duo, core, 500gb, 4gb, 226ghz]
# 21632158                                              [ram, pro, mac, apple, pcie, ssd, 35ghz, firepro, 64gb, 16gb]
# 24215399                             [watch, charging, apple, for_apple, dock, stand, support, base, watch., cable]
# 2425                                  [protector, screen, watch, for_apple, apple, tempered, glass, 42mm, mm, zagg]
# 2434                         [watch, apple, case, housing, for_apple, anti-shock, watch., 42mm, survivor, tactical]
# 2449                                       [strap, apple, watch, 42mm, 38mm, sports, for_apple, mm, black, leather]
# 24811716                                        [plus, iphone, 6s, apple, 32gb, new, gold, free, refurbished, 16gb]
# 24821716                                       [6s, iphone, apple, new, 32gb, free, gold, like, refurbished, 128gb]
# 24861714                                         [mini, ipad, 4, apple, wi-fi, 32gb, cellular, 32gb., gold, wi-fi.]
# 24885185                               [watch, apple, 38mm, strap, case, sport, series, aluminum, gps, submersible]
# 24895185                                      [watch, apple, 42mm, strap, case, aluminum, sport, series, gps, nike]
# 4259                                  [apple, player, media, multimedia, tv, like, new, player., refurbished, 64gb]
# 42931714                                               [air, 2, wi-fi, ipad, apple, 32gb, new, like, silver, space]
# 42945397                           [lightning, usb, pendrive, for_iphone, 2.0, 64gb, wireless, sandisk, flash, 3.0]
# 5,39E+11                                             [macbook, core, ssd, ram, retina, 256gb, 8gb, 12", apple, new]
# 5,43E+15                                                        [2, core, ram, hdd, imac, duo, 2gb, 160gb, 20", 20]
# 5,44E+11                                               [core, mac, mini, ram, 4gb, i5, hdd, apple, computer, 500gb]
# 5,45E+15                                                      [ram, mini, mac, hdd, duo, core, 4gb, 320gb, 2, hand]
# 5,49E+11                                     [battery, case, iphone, 6, 6s, for_iphone, pack, mophie, juice, black]
# 5,72E+15                                       [imac, hdd, core, ram, 4gb, i5, second, refurbished, hand, computer]
# 5,74E+15                                         [5k, imac, retina, ram, core, apple, 27", computer, desktop, inch]
# 51601716                                                [iphone, apple, new, se, free, 16gb, like, gold, 5s, space]
# 5185                                        [1st, watch, the, strap, steel, stainless, leather, apple, color, case]
# 51861714                                            [ipad, pro, wi-fi, apple, 12.9", new, inch, 512gb, 256gb, 12.9]
# 51871714                                         [pro, ipad, wi-fi, apple, 9.7", 128gb, 32gb, 9.7-inch, space, new]
# 51882158                                                    [imac, core, ram, 4gb, apple, hdd, 2, inch, retina, 5k]
# 51902158                                        [ram, macbook, i5, flash, air, 8gb, 16ghz, 128gb, refurbished, 13"]
# 51912158                                             [pro, macbook, core, bar, 28ghz, 256gb, 16gb, i7, pcie, touch]
# 5384                       [headphones, ipad, wireless, headset, ipod, bluetooth, for_iphone, beats, black, iphone]
# 5395                     [usb, strip, adapter, outlets, allocacoc, powercube, electrical, white, 250v, cube-shaped]
# 5398                     [speaker, bluetooth, ipad, for_iphone, portable, wireless, ipod, black, ipod., waterproof]
# 5399                                        [wireless, qi, charging, charger, 8, iphone, x, plus, base, for_iphone]
# 5401                                 [mac, keyboard, bluetooth, aluminum, spanish, keypad, open, matias, ios, ipad]
# 54025401                         [keyboard, ipad, wireless, black, apple, bluetooth, mechanical, tv., spanish, pro]
# 5403                                           [case, pro, plus, iphone, cover, keyboard, 5, 5s, apple, for_iphone]
# 5404                         [camera, personal, radar, robot, action, black, video, lamp, polaroid, transportation]
# 5405                                          [armband, plus, 6, iphone, sport, bracelet, for_iphone, black, 6s, 7]
# 5406                                    [3/4, screwdriver, panel, ipad, ifixit, front, kit, iphone, full, for_ipad]
# 5407                            [adhesive, battery, strips, 6, for_iphone, ifixit, iphone, part, replacement, plus]
# 54085407                                     [pro, mid, macbook, ifixit, fan, bracket, for_macbook, cable, 13, 13"]
# 54864259                               [apple, remote, case, siri, tv, media, control, player, survivor, for_apple]
# 5720                           [support, iphone, stand, for_iphone, aluminum, car, holder, lightning, elago, cable]
# 57445397                                               [card, memory, class, usb, s, 64gb, uhs, sandisk, 32gb, 3.0]
# 79201715                                    [touch, ipod, 32gb, new, like, apple, 16gb, blue, in, sixth-generation]
# 85641716                                             [7, iphone, apple, free, new, black, gold, 128gb, 256gb, 32gb]
# 85651716                                             [plus, iphone, 7, apple, new, free, black, 128gb, 256gb, gold]
# 8696                                  [support, macbook, aluminum, pro, for_macbook, stand, imac, design, air, mac]
# 9,29E+11                                       [16gb, 512gb, english, core, bar, i7, keyboard, touch, ssd, macbook]
# 9094                                    [camera, surveillance, hd, arlo, netgear, ipad, night, 2, security, vision]
#
#                                                                                                                                    word_freqs
# type
# 1,02E+12                                   [pro:300, macbook:260, ssd:254, core:253, touch:184, bar:184, 16gb:170, i7:163, ram:159, pcie:154]
# 1,44E+11   [repair:243, service:122, including_parts_and_labor:117, iphone:77, for_iphone:76, for_ipad:49, ipad:46, 2:40, screen:34, mini:30]
# 10142                                [battery:45, macbook:35, pro:23, nupower:17, newertech:17, late:12, 13":11, air:10, early:10, unibody:9]
# 101781405                             [wacom:14, intuos:8, cintiq:8, tips:7, replacement:5, kit:4, 4:4, accessory:4, graphics:3, for_wacom:3]
# 10230                                            [macbook:52, pro:47, retina:34, black:20, case:19, tucano:15, bag:14, 15:13, 15":13, 13":13]
# 106431714                                   [pro:57, ipad:57, wi-fi:54, apple:29, cellular:29, new:27, 10.5":26, 64gb:24, 256gb:17, 512gb:16]
# 113271716                                             [iphone:8, x:8, 64gb:6, new:4, gray:4, free:4, space:4, apple:4, refurbished:2, like:2]
# 113281716                                         [iphone:32, plus:32, apple:32, 8:32, 64gb:18, space:14, 256gb:14, gray:14, gold:10, free:9]
# 113291716                                          [apple:26, iphone:26, 8:26, 64gb:14, gold:12, 256gb:12, silver:8, free:6, gray:6, space:6]
# 113464259                                                                [open:2, apple:2, multimedia:1, player:1, tv:1, box:1, 4k:1, 32gb:1]
# 113851714                                            [ipad:4, wi-fi:4, apple:3, gray:2, 32gb:2, 128gb:2, silver:2, space:2, (mp2h2ty:1, a):1]
# 11434                                        [pro:2, adapter:2, security:1, (end:1, 2013).:1, apple:1, cable:1, for_mac:1, for_the:1, lock:1]
# 11821715                           [ipod:116, touch:64, apple:58, 16gb:48, generation:46, new:36, nano:32, player:26, music:26, megapixel:24]
# 11859            [homekit:4, fibaro:3, sensor:3, multi-sensor:2, movement:2, compatible:2, temperature:1, water:1, multi-function:1, flood:1]
# 11865403                          [case:1577, iphone:1285, 6:841, plus:829, for_iphone:752, 6s:572, 7:489, cover:430, black:349, leather:333]
# 118692158                                [pro:216, xeon:144, imac:144, w:144, intel:143, processor:72, vega:72, ssd:72, screen:72, retina:72]
# 11905404                  [ipad:221, for_iphone:199, iphone:150, ipod:133, bluetooth:99, white:93, control:91, app:78, black:73, activity:70]
# 11935397                [hard:584, drive:566, usb:558, 3.0:478, external:416, for_mac:384, pc:364, thunderbolt:348, raid:215, connection:162]
# 12031714                                                [mini:10, 2:10, ipad:10, apple:7, space:6, 32gb:6, gray:6, wi-fi:6, 16gb:4, silver:3]
# 12051714                          [air:6, ipad:5, wi-fi:4, 16gb:4, apple:2, gray:2, repair:2, silver:2, space:2, including_parts_and_labor:1]
# 12085400                                   [cleaner:3, ipad:3, spray:3, iphone:2, ipod:2, mac:2, screens:2, spray.:2, display:2, bluetooth:2]
# 12141714                                           [ipad:64, wi-fi:58, apple:41, cellular:32, pro:30, air:26, 2:26, new:23, 9.7":15, 32gb:14]
# 1216                   [support:81, ipad:77, security:29, pro:27, stand:26, black:26, for_ipad:23, adjustable:23, securityxtra:22, iphone:20]
# 12175397                          [nas:1317, server:902, ram:835, synology:718, seagate:606, wd:567, for_mac:563, pack:524, pc:474, qnap:455]
# 12215397                                     [ssd:335, pro:122, kit:91, owc:84, expansion:83, macbook:82, air:79, sata:76, hard:68, 240gb:66]
# 12282                                  [watch:2, compact:1, black:1, belkin:1, apple:1, support:1, stand:1, portable:1, or:1, horizontally:1]
# 12285400                                      [ipad:8, iphone:7, cable:4, ipod:3, ipod.:3, black:2, bluelounge:2, cabledrop:2, gloves:2, 6:2]
# 1229                                [pointer:95, pen:67, stylus:56, digital:46, wacom:42, ipad:37, jot:36, adonit:35, bamboo:31, for_ipad:30]
# 1230                           [cable:118, lightning:116, usb:100, ipad:55, ipod:46, iphone:40, for_iphone:30, apple:26, white:24, charge:19]
# 1231                                [warranty:10, extended:10, applecare:10, apple:10, protection:9, care:9, plan:7, macbook:7, pro:6, mac:4]
# 12355400                               [gopro:9, calibrator:9, usb:8, support:8, color:8, magic:6, adapter:6, battery:5, macbook:5, x-rite:5]
# 12575403                                     [keyboard:48, ipad:29, folio:20, air:19, cover:17, for_ipad:16, black:15, pro:14, 2:14, case:13]
# 12585395                           [usb:250, adapter:204, usb-c:145, 3.0:96, hdmi:89, hub:87, for_mac:77, ethernet:74, thunderbolt:69, pc:65]
# 12635403                               [ipad:468, case:453, pro:279, cover:247, mini:218, for_ipad:174, apple:165, air:162, smart:160, 4:128]
# 12645406                 [kit:44, ifixit:42, iphone:32, for_iphone:32, battery:31, tools:25, 5:17, screwdriver:16, change:15, replacement:15]
# 12655397                                         [hard:159, drive:134, pc:93, sata:85, 35":64, mac:62, nas:56, wd:54, digital:51, western:51]
# 12755395                                      [kit:25, adapter:24, ssd:23, owc:22, mac:17, pro:16, mini:16, bay:15, hard:14, installation:14]
# 1276                                                 [card:24, pcie:22, sonnet:12, for_mac:11, esata:10, adapter:9, pro:8, s:8, ssd:8, 6gb:8]
# 1280                                         [expansion:6, nas:5, mac:4, pc:4, synology:4, server:3, unit:3, rackstation:2, module:2, mini:2]
# 1282                                   [ram:610, apple:447, core:357, flash:349, i5:336, 8gb:311, imac:302, retina:269, macbook:258, pro:256]
# 1296                                              [monitor:352, hdmi:116, for_mac:110, pc:96, ips:64, 4k:62, dell:59, lg:58, benq:57, 99%:55]
# 1298                                   [open:550, pro:248, (open):217, usb:212, case:206, macbook:199, iphone:191, pc:186, hard:171, mac:164]
# 12995397                                        [thunderbolt:73, usb:72, external:47, 3.0:47, pc:41, 3:39, for_mac:39, dock:38, box:37, 2:34]
# 13005399                             [charger:43, macbook:38, magsafe:33, air:23, apple:23, battery:22, pro:22, 2:16, for_macbook:13, mid:12]
# 1325                                  [cable:275, usb:110, thunderbolt:99, adapter:77, hdmi:65, usb-c:60, mini:56, belkin:51, 3:46, black:39]
# 1334                           [d-link:67, router:58, gigabit:55, wireless:47, wi-fi:45, switch:41, kit:37, wifi:35, adapter:32, ethernet:28]
# 13555403                           [6:96, iphone:94, glass:85, protector:81, plus:79, 6s:66, screen:63, for_iphone:49, tempered:45, saver:20]
# 13615399                       [charger:95, iphone:62, car:56, usb:53, lightning:52, belkin:34, charging:30, dock:29, for_iphone:28, base:20]
# 13621714                                          [apple:38, ipad:38, mini:38, 4:36, wi-fi:31, cellular:20, 16gb:11, 64gb:9, gray:8, space:8]
# 1364                                         [mac:358, memory:253, ram:195, so-dimm:154, ddr3:131, pro:131, imac:127, owc:99, 8gb:97, 4gb:88]
# 1375            [microphone:18, usb:14, blue:10, microphones:9, for_mac:9, snowball:5, connection:5, professional:5, capsules:4, different:4]
# 13835403                          [macbook:408, pro:297, case:247, air:165, 13":151, retina:138, for_macbook:124, black:97, sleeve:95, 13:91]
# 13855401                    [keyboard:61, mac:30, bluetooth:24, keypad:24, wireless:21, apple:21, spanish:17, ipad:9, ultrathin:9, for_mac:8]
# 1387                             [mouse:32, wireless:18, apple:14, for_mac:11, aluminum:8, trackpad:8, logitech:8, magic:7, 2:7, bluetooth:7]
# 1392                                [backpack:113, macbook:89, pro:62, 15":40, 13":37, black:32, for_macbook:32, retina:30, air:26, thule:20]
# 13955395                                   [connector:5, apple:4, ipad:4, sd:3, adapter:3, camera:2, cameras:2, card:2, connection:2, dock:2]
# 14035403                                     [protector:32, screen:31, ipad:26, for_ipad:16, air:16, mini:11, pro:10, 2:9, ivisor:8, moshi:8]
# 1404                                            [expansion:21, qnap:21, synology:20, nas:17, card:10, kit:9, rail:9, bays:7, ssd:7, memory:7]
# 1405                                     [tablet:95, graphics:80, wacom:76, pen:71, for_mac:54, pro:50, intuos:50, pc:38, black:26, touch:26]
# 1416                                        [adobe:21, for_mac:19, cc:18, software:15, pc.:11, license:11, mac:9, update:8, office:8, home:8]
# 1424                                            [recorder:11, external:10, dvd:8, slim:7, ultra:5, pro:4, samsung:4, usb:4, video:4, white:4]
# 14305406                         [kit:32, ifixit:26, imac:19, macbook:18, pro:16, tool:14, tools:14, installation:13, ssd:12, screwdriver:12]
# 1433                             [kit:344, ssd:332, expansion:203, pro:167, datadoubler:117, mini:117, imac:114, tools:112, ram:112, mid:111]
# 14365395                               [adapter:33, lightning:22, iphone:16, ipod:15, apple:13, 5:10, connector:10, for_iphone:9, car:8, 6:8]
# 1515                             [battery:153, external:93, usb:74, for_iphone:57, mah:36, power:31, ipad:29, mophie:25, mirror:18, small:18]
# 15435404                                  [for_mac:3, pro:3, fhd:2, controller:2, korg:2, littlebits:2, sensor:2, security:2, pc:2, motion:2]
# 1714                                            [ipad:56, wi-fi:50, apple:30, new:27, pro:26, cellular:25, 128gb:23, gold:16, 32gb:16, a):14]
# 1716                                                      [apple:55, iphone:48, open:23, new:23, a):23, gb:20, 6s:20, like:19, free:15, 7:13]
# 2,16E+11                                              [imac:84, 1tb:48, ram:48, ssd:47, core:43, apple:43, inch:40, 215:40, 21.5":36, 8gb:35]
# 2,17E+11                                                [macbook:72, ram:64, 8gb:44, air:38, ssd:37, apple:36, i7:36, i5:36, core:30, 13":28]
# 20642062                                      [installation:16, ssd:10, ram:10, macbook:8, pro:8, service:8, hdd:6, mac:6, in:5, transfer.:5]
# 21485407                            [iphone:90, piece:63, ifixit:51, for_iphone:41, 5:40, 5s:34, replacement:31, 6:27, battery:20, button:20]
# 21535407                                       [ipad:20, panel:16, front:13, for_ipad:11, ifixit:11, 2:9, 3/4:6, battery:6, white:6, tools:5]
# 21561716                                            [6:10, iphone:10, apple:9, space:8, gray:8, new:5, 16gb:4, 32gb:4, like:4, refurbished:3]
# 21571716                                         [apple:10, 6:10, plus:10, iphone:10, new:5, like:5, free:5, silver:4, refurbished:4, 16gb:4]
# 2158                                       [pro:269, ssd:214, ram:214, pcie:214, macbook:214, core:192, bar:170, touch:170, 16gb:155, i7:146]
# 21622158                                                          [2:2, ram:2, mini:2, mac:2, hdd:2, duo:2, core:2, 500gb:2, 4gb:2, 226ghz:2]
# 21632158                                          [ram:74, pro:74, mac:74, apple:56, pcie:56, ssd:40, 35ghz:36, firepro:26, 64gb:26, 16gb:25]
# 24215399                         [watch:66, charging:49, apple:48, for_apple:34, dock:23, stand:23, support:17, base:16, watch.:15, cable:14]
# 2425                                       [protector:10, screen:8, watch:8, for_apple:5, apple:5, tempered:4, glass:3, 42mm:3, mm:2, zagg:2]
# 2434                     [watch:35, apple:31, case:24, housing:23, for_apple:21, anti-shock:19, watch.:17, 42mm:17, survivor:11, tactical:11]
# 2449                                [strap:188, apple:169, watch:159, 42mm:89, 38mm:56, sports:48, for_apple:47, mm:41, black:40, leather:35]
# 24811716                                    [plus:34, iphone:34, 6s:34, apple:30, 32gb:18, new:15, gold:13, free:12, refurbished:10, 16gb:10]
# 24821716                                   [6s:40, iphone:40, apple:32, new:19, 32gb:16, free:15, gold:14, like:11, refurbished:10, 128gb:10]
# 24861714                                          [mini:14, ipad:14, 4:14, apple:14, wi-fi:11, 32gb:9, cellular:6, 32gb.:3, gold:3, wi-fi.:3]
# 24885185                         [watch:134, apple:134, 38mm:92, strap:64, case:61, sport:58, series:55, aluminum:47, gps:46, submersible:33]
# 24895185                                [watch:134, apple:134, 42mm:88, strap:81, case:62, aluminum:58, sport:55, series:54, gps:48, nike:39]
# 4259                                       [apple:12, player:9, media:6, multimedia:6, tv:6, like:3, new:3, player.:3, refurbished:3, 64gb:2]
# 42931714                                                [air:16, 2:16, wi-fi:16, ipad:16, apple:13, 32gb:8, new:7, like:5, silver:4, space:4]
# 42945397                       [lightning:56, usb:52, pendrive:30, for_iphone:28, 2.0:25, 64gb:22, wireless:21, sandisk:20, flash:20, 3.0:20]
# 5,39E+11                                         [macbook:94, core:92, ssd:86, ram:62, retina:59, 256gb:56, 8gb:54, 12":47, apple:47, new:44]
# 5,43E+15                                                    [2:28, core:28, ram:28, hdd:28, imac:28, duo:28, 2gb:22, 160gb:18, 20":14, 20:14]
# 5,44E+11                                                  [core:10, mac:10, mini:10, ram:9, 4gb:8, i5:8, hdd:7, apple:5, computer:5, 500gb:4]
# 5,45E+15                                                            [ram:2, mini:2, mac:2, hdd:2, duo:2, core:2, 4gb:2, 320gb:2, 2:2, hand:1]
# 5,49E+11                                 [battery:97, case:75, iphone:59, 6:47, 6s:32, for_iphone:32, pack:26, mophie:26, juice:24, black:20]
# 5,72E+15                                        [imac:12, hdd:12, core:12, ram:12, 4gb:10, i5:8, second:6, refurbished:6, hand:6, computer:6]
# 5,74E+15                           [5k:494, imac:494, retina:491, ram:291, core:288, apple:251, 27":247, computer:239, desktop:237, inch:222]
# 51601716                                            [iphone:86, apple:53, new:38, se:32, free:30, 16gb:28, like:25, gold:23, 5s:20, space:19]
# 5185                                              [1st:2, watch:2, the:2, strap:2, steel:2, stainless:2, leather:2, apple:2, color:1, case:1]
# 51861714                                        [ipad:56, pro:56, wi-fi:53, apple:29, 12.9":28, new:25, inch:16, 512gb:16, 256gb:16, 12.9:16]
# 51871714                                       [pro:30, ipad:30, wi-fi:23, apple:20, 9.7":15, 128gb:14, 32gb:13, 9.7-inch:13, space:9, new:8]
# 51882158                                                    [imac:20, core:18, ram:17, 4gb:12, apple:10, hdd:10, 2:9, inch:9, retina:8, 5k:8]
# 51902158                                              [ram:2, macbook:2, i5:2, flash:2, air:2, 8gb:2, 16ghz:2, 128gb:2, refurbished:1, 13":1]
# 51912158                                                   [pro:3, macbook:2, core:2, bar:2, 28ghz:2, 256gb:2, 16gb:2, i7:2, pcie:2, touch:2]
# 5384            [headphones:179, ipad:133, wireless:121, headset:120, ipod:111, bluetooth:111, for_iphone:110, beats:56, black:56, iphone:44]
# 5395                 [usb:29, strip:22, adapter:21, outlets:20, allocacoc:18, powercube:18, electrical:18, white:17, 250v:17, cube-shaped:16]
# 5398              [speaker:248, bluetooth:177, ipad:109, for_iphone:99, portable:75, wireless:74, ipod:58, black:57, ipod.:48, waterproof:38]
# 5399                                       [wireless:21, qi:20, charging:15, charger:15, 8:13, iphone:11, x:10, plus:7, base:7, for_iphone:6]
# 5401                                       [mac:9, keyboard:8, bluetooth:8, aluminum:6, spanish:5, keypad:4, open:3, matias:3, ios:3, ipad:3]
# 54025401                               [keyboard:6, ipad:3, wireless:2, black:2, apple:2, bluetooth:2, mechanical:2, tv.:2, spanish:2, pro:2]
# 5403                                             [case:22, pro:12, plus:10, iphone:10, cover:7, keyboard:7, 5:7, 5s:6, apple:6, for_iphone:6]
# 5404                               [camera:6, personal:6, radar:6, robot:6, action:5, black:5, video:4, lamp:4, polaroid:4, transportation:3]
# 5405                                      [armband:47, plus:43, 6:35, iphone:34, sport:29, bracelet:27, for_iphone:25, black:24, 6s:23, 7:20]
# 5406                                          [3/4:2, screwdriver:2, panel:2, ipad:2, ifixit:2, front:2, kit:1, iphone:1, full:1, for_ipad:1]
# 5407                                  [adhesive:6, battery:6, strips:6, 6:4, for_iphone:3, ifixit:3, iphone:3, part:3, replacement:3, plus:2]
# 54085407                                        [pro:17, mid:15, macbook:11, ifixit:9, fan:8, bracket:8, for_macbook:7, cable:6, 13:6, 13":6]
# 54864259                                   [apple:12, remote:11, case:6, siri:6, tv:5, media:4, control:4, player:4, survivor:3, for_apple:3]
# 5720                       [support:37, iphone:29, stand:28, for_iphone:23, aluminum:19, car:17, holder:14, lightning:13, elago:12, cable:11]
# 57445397                                         [card:141, memory:130, class:96, usb:90, s:83, 64gb:65, uhs:58, sandisk:50, 32gb:49, 3.0:46]
# 79201715                                          [touch:6, ipod:6, 32gb:4, new:3, like:3, apple:3, 16gb:2, blue:2, in:2, sixth-generation:2]
# 85641716                                         [7:64, iphone:64, apple:63, free:31, new:30, black:24, gold:24, 128gb:22, 256gb:21, 32gb:20]
# 85651716                                         [plus:84, iphone:84, 7:84, apple:82, new:43, free:38, black:29, 128gb:29, 256gb:26, gold:25]
# 8696                              [support:74, macbook:58, aluminum:35, pro:28, for_macbook:21, stand:16, imac:15, design:15, air:13, mac:12]
# 9,29E+11                                             [16gb:2, 512gb:2, english:2, core:2, bar:2, i7:2, keyboard:2, touch:2, ssd:2, macbook:2]
# 9094                                [camera:74, surveillance:37, hd:35, arlo:33, netgear:31, ipad:28, night:24, 2:23, security:23, vision:23]
